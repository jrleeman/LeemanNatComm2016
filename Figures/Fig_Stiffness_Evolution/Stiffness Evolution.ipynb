# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
exps = ['p4267','p4268','p4269','p4270','p4271','p4272','p4273',
        'p4309','p4310','p4311','p4312','p4313','p4314','p4316','p4317',
        'p4327','p4328','p4329','p4330','p4338','p4339']

# %%
exp_list = pd.read_table('../../experiment_list.md',delimiter='|',skiprows=[1],usecols=[1,2,3,4,5,6,7],skipinitialspace=True)
exp_list
# Out:
#     Experiment   Blocks Used        Normal Stress [MPa]   Temperature [C]   \
# 0   p4224        Titanium/Acrylic                      5              26.0
# 1   p4228        Steel                                 4              24.0
# 2   p4229        Titanium/Acrylic                      4              24.0
# 3   p4248        Titanium/Acrylic                      4              24.2
# 4   p4249        Titanium/Acrylic                      4              23.2
# 5   p4267        Titanium/Acrylic                      2              23.2
# 6   p4268        Titanium/Acrylic                      8              23.4
# 7   p4269        Steel                                 4              23.4
# 8   p4270        Steel                                 2               NaN
# 9   p4271        Titanium/Acrylic                      2               NaN
# 10  p4272        Titanium/Acrylic                      8              22.7
# 11  p4273        Steel                                 8              23.4
# 12  p4309        Steel                                 8              23.2
# 13  p4310        Titanium/Acrylic                      8              24.2
# 14  p4311        Titanium/Acrylic                      8              23.3
# 15  p4312        Steel/Acrylic                         8              23.6
# 16  p4313        Titanium/Acrylic                      8              23.5
# 17  p4314        Steel                                12              24.3
# 18  p4316        Titanium/Acrylic                     12              23.6
# 19  p4317        Steel/Acrylic                        12              24.2
# 20  p4327        Steel                                 6              22.5
# 21  p4328        Titanium/Acrylic                      6              22.7
# 22  p4329        Titanium/Acrylic                      6              22.0
# 23  p4330        Steel                                 6              22.9
# 24  p4338        Titanium/Acrylic                      4              24.2
# 25  p4339        Steel                                 4              24.8
#
#     Relative Humidity [%]   Comments                          Unload/Reloads
# 0                       16  Stable - Velocity Steps           N
# 1                      100  Stable - Slide Hold Slide         N
# 2                      100  Failed Experiment                 N
# 3                      100  Stable - Velocity Steps           N
# 4                      100  Stable - Velocity Steps           N
# 5                      100  Stable - Velocity Steps           Y
# 6                      100  Slow Slip                         Y
# 7                      100  Stable - Velocity Steps           Y
# 8                      100  Stable - Velocity Steps           Y
# 9                      100  Stable - Velocity Steps           Y
# 10                     100  Slow Slip                         Y
# 11                     100  Stable - Velocity Steps           Y
# 12                     100  Stable - Velocity Steps           Y
# 13                     100  Slow Slip                         Y
# 14                     100  Slow Slip                         Y
# 15                     100  Slow Slip                         Y
# 16                     100  Slow Slip                         Y
# 17                     100  Stable - Velocity Steps           Y
# 18                     100  Stick Slip                        Y
# 19                     100  Stick Slip                        Y
# 20                     100  Stable - Velocity Steps           Y
# 21                     100  Slow Slip                         Y
# 22                     100  Slow Slip                         Y
# 23                     100  Stable - Velocity Steps           Y
# 24                     100  Stable - Velocity Steps           Y
# 25                     100  Stable - Velocity Steps           Y

# %%
# Setup figure and axes
fig = plt.figure(figsize=(12,9))
ax1 = plt.subplot(111)

# Set labels and tick sizes
ax1.set_xlabel(r'Average LP Displacement [mm]',fontsize=18)
ax1.set_ylabel(r'Stiffness [1/um]',fontsize=18)
ax1.tick_params(axis='both', which='major', labelsize=16)

# Turns off chart clutter

# Turn off top and right tick marks
ax1.get_xaxis().tick_bottom()
ax1.get_yaxis().tick_left()

# Turn off top and right splines
ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)

# Plotting

for exp in exps:

    details = exp_list[exp_list['Experiment ']=='%s      '%exp]
    nor_stress = details['Normal Stress [MPa] ']
    df = pd.read_csv('%s_stiffness_cycles.txt'%exp)

    temp = df[df['Behavior']=='stable']
    ax1.scatter(temp['AvgDisp']/1000.,temp['Slope'],color='g',s=(nor_stress*1)**2,alpha=0.6)

    temp = df[df['Behavior']=='slow']
    ax1.scatter(temp['AvgDisp']/1000.,temp['Slope'],color='y',s=(nor_stress*1)**2,alpha=0.6)

    temp = df[df['Behavior']=='fast']
    ax1.scatter(temp['AvgDisp']/1000.,temp['Slope'],color='r',s=(nor_stress*1)**2,alpha=0.6)

# Set limits
ax1.set_xlim(0,50)
ax1.set_ylim(0,0.006)

# Plot Kc
df = pd.read_excel('p4309_rsf_fits.xlsx')




for i,fit in df.iterrows():

    if fit['Grade'] == 'A':
        color='#000066'
    elif fit['Grade'] == 'B':
        color='#0066CC'
    elif fit['Grade'] == 'C':
        color='#00CCFF'
        color='#000000'
    elif fit['Grade'] == 'D':
        color='#00FFFF'
        color='#000000'

    if fit['Type']=='Down' and fit['Law']=='r' and fit['k']==0.0055:
        ax1.scatter(fit['LP_Disp']/1000.,fit['Kc'],c=color,s=60,marker='v')
    elif fit['Type']=='Up' and fit['Law']=='r' and fit['k']==0.0055:
        ax1.scatter(fit['LP_Disp']/1000.,fit['Kc'],c=color,s=60,marker='^')
    else:
        pass

plt.savefig('Stiffness_Evolution.pdf',bbox_inches='tight')
